# %%
import pandas as pd
import numpy as np
import acquire as a
import new_lib as nl
import prepare as p
from sklearn.preprocessing import MinMaxScaler

# %%
wine = a.acquire_wine()
wine
# Out:
#       red_or_white  fixed acidity  volatile acidity  citric acid  \
# 0                1            7.4              0.70         0.00
# 1                1            7.8              0.88         0.00
# 2                1            7.8              0.76         0.04
# 3                1           11.2              0.28         0.56
# 4                1            7.4              0.70         0.00
# ...            ...            ...               ...          ...
# 6492             0            6.2              0.21         0.29
# 6493             0            6.6              0.32         0.36
# 6494             0            6.5              0.24         0.19
# 6495             0            5.5              0.29         0.30
# 6496             0            6.0              0.21         0.38
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                1.9      0.076                 11.0                  34.0
# ...

# %%
wine[wine.red_or_white == 1]
# Out:
#       red_or_white  fixed acidity  volatile acidity  citric acid  \
# 0                1            7.4             0.700         0.00
# 1                1            7.8             0.880         0.00
# 2                1            7.8             0.760         0.04
# 3                1           11.2             0.280         0.56
# 4                1            7.4             0.700         0.00
# ...            ...            ...               ...          ...
# 1594             1            6.2             0.600         0.08
# 1595             1            5.9             0.550         0.10
# 1596             1            6.3             0.510         0.13
# 1597             1            5.9             0.645         0.12
# 1598             1            6.0             0.310         0.47
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                1.9      0.076                 11.0                  34.0
# ...

# %%
wine[wine.red_or_white == 0]
# Out:
#       red_or_white  fixed acidity  volatile acidity  citric acid  \
# 1599             0            7.0              0.27         0.36
# 1600             0            6.3              0.30         0.34
# 1601             0            8.1              0.28         0.40
# 1602             0            7.2              0.23         0.32
# 1603             0            7.2              0.23         0.32
# ...            ...            ...               ...          ...
# 6492             0            6.2              0.21         0.29
# 6493             0            6.6              0.32         0.36
# 6494             0            6.5              0.24         0.19
# 6495             0            5.5              0.29         0.30
# 6496             0            6.0              0.21         0.38
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 1599            20.7      0.045                 45.0                 170.0
# ...

# %%
wine = p.prepare_wine(wine)
wine
# Out:
#       red_or_white  fixed acidity  volatile acidity  citric acid  \
# 0                1            7.4              0.70         0.00
# 1                1            7.8              0.88         0.00
# 2                1            7.8              0.76         0.04
# 3                1           11.2              0.28         0.56
# 4                1            7.4              0.70         0.00
# ...            ...            ...               ...          ...
# 6492             0            6.2              0.21         0.29
# 6493             0            6.6              0.32         0.36
# 6494             0            6.5              0.24         0.19
# 6495             0            5.5              0.29         0.30
# 6496             0            6.0              0.21         0.38
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                1.9      0.076                 11.0                  34.0
# ...
